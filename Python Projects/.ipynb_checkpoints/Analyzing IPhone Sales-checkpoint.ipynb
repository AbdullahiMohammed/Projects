# %% [markdown]
# # CONTENT
# * Import libraries and dataset
# * Descriptive Analysis
# * Basic Descriptions
# * Pandas Profiling
# * Handling missing Values
# * Sales Data Analysis

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import dataset

file = pd.read_csv('datasets_python/apple_products.xls')

# %%
# Pandas Profiling
file
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
file.shape
# Out:
# (62, 11)

# %%
file.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
file.tail()
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 57  39900                   24              95909               8161
# 58  54900                   14              43470               3331
# 59  54900                   14              43470               3331
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     int64
#  6   Number Of Ratings    62 non-null     int64
#  7   Number Of Reviews    62 non-null     int64
#  8   Upc                  62 non-null     object
#  9   Star Rating          62 non-null     float64
#  10  Ram                  62 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 5.5+ KB

# %%
file.columns
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Discount Percentage', 'Number Of Ratings', 'Number Of Reviews', 'Upc',
#        'Star Rating', 'Ram'],
#       dtype='object')

# %%
file.describe(include='all')
# Out:
#                              Product Name  \
# count                                  62
# unique                                 62
# top     APPLE iPhone 8 Plus (Gold, 64 GB)
# freq                                    1
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN
#
#                                               Product URL  Brand  \
# count                                                  62     62
# unique                                                 62      1
# top     https://www.flipkart.com/apple-iphone-8-plus-g...  Apple
# freq                                                    1     62
# mean                                                  NaN    NaN
# ...

# %% [markdown]
# # HANDLING MISSING VALUES

# %%
file.isnull().sum()
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %% [markdown]
# # <center><span>SALES DATA ANALYSIS</span></center>

# %%
# HIGHEST RATED PRODUCTS

highest_rated = file.sort_values(by='Star Rating',ascending=False)[:10]
highest_rated

# %%
highest_rated_product = highest_rated['Product Name']
highest_rated_product
# Out:
# 20     APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17         APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16    APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15               APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14              APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 0                    APPLE iPhone 8 Plus (Gold, 64 GB)
# 29                     APPLE iPhone 12 (White, 128 GB)
# 32          APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 35                     APPLE iPhone 12 (Black, 128 GB)
# 36                      APPLE iPhone 12 (Blue, 128 GB)
# Name: Product Name, dtype: object

# %%
iphone_names = highest_rated['Product Name'].value_counts()
iphone_names
# Out:
# APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)     1
# APPLE iPhone 11 Pro Max (Space Grey, 64 GB)         1
# APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)    1
# APPLE iPhone 11 Pro Max (Gold, 64 GB)               1
# APPLE iPhone 11 Pro Max (Gold, 256 GB)              1
# APPLE iPhone 8 Plus (Gold, 64 GB)                   1
# APPLE iPhone 12 (White, 128 GB)                     1
# APPLE iPhone 12 Pro Max (Graphite, 128 GB)          1
# APPLE iPhone 12 (Black, 128 GB)                     1
# APPLE iPhone 12 (Blue, 128 GB)                      1
# Name: Product Name, dtype: int64

# %%
label = iphone_names.index
label
# Out:
# Index(['APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)',
#        'APPLE iPhone 11 Pro Max (Space Grey, 64 GB)',
#        'APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)',
#        'APPLE iPhone 11 Pro Max (Gold, 64 GB)',
#        'APPLE iPhone 11 Pro Max (Gold, 256 GB)',
#        'APPLE iPhone 8 Plus (Gold, 64 GB)', 'APPLE iPhone 12 (White, 128 GB)',
#        'APPLE iPhone 12 Pro Max (Graphite, 128 GB)',
#        'APPLE iPhone 12 (Black, 128 GB)', 'APPLE iPhone 12 (Blue, 128 GB)'],
#       dtype='object')

# %%
counts = highest_rated['Number Of Ratings']
counts.index
# Out:
# Int64Index([20, 17, 16, 15, 14, 0, 29, 32, 35, 36], dtype='int64')

# %%
plt.barh(label,counts)
plt.show()

# %%
# PRODUCTS WITH THE HIGHEST REVIEWS
reviews = highest_rated['Number Of Reviews']

plt.barh(label, reviews)
plt.show()

# %%
# RELATIONSHIP BETWEEN SALES PRICE AND NUMBER OF REVIEWS

plt.scatter(reviews, label, marker='x')
plt.show()

# %%
# RELATIONSHIP BETWEEN SALES PRICE AND STAR RATINGS

plt.scatter(counts, label, marker='x')
plt.show()
