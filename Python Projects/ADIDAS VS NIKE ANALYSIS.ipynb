# %% [markdown]
# # CONTENT
#
# * DESCRIPTIVE ANALYSIS
#     1. IMPORT DATA AND LIBRARIES
#     2. BASIC DESCRIPTION OF DATA
#     3. HANDLING MISSING VALUES
# * ANALYSIS

# %%
#IMPORT DATA AND LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime


data = pd.read_csv('datasets_python/Adidas Vs Nike.csv')

# %%
#BASIC DESCRIPTION OF DATA

data
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
head = data.head()
tail = data.tail()

columns = data.columns
desc = data.describe(include='all')

head
# Out:
#                                         Product Name Product ID  \
# 0  Women's adidas Originals NMD_Racer Primeknit S...     AH2430
# 1               Women's adidas Originals Sleek Shoes     G27341
# 2                  Women's adidas Swim Puka Slippers     CM0081
# 3   Women's adidas Sport Inspired Questar Ride Shoes     B44832
# 4           Women's adidas Originals Taekwondo Shoes     D98205
#
#    Listing Price  Sale Price  Discount                    Brand  \
# 0          14999        7499        50  Adidas Adidas ORIGINALS
# 1           7599        3799        50         Adidas ORIGINALS
# 2            999         599        40        Adidas CORE / NEO
# 3           6999        3499        50        Adidas CORE / NEO
# 4           7999        3999        50         Adidas ORIGINALS
#
#                                          Description  Rating  Reviews  \
# 0  Channeling the streamlined look of an '80s rac...     4.8       41
# ...

# %%
info = data.info()
info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   3268 non-null   object
#  1   Product ID     3268 non-null   object
#  2   Listing Price  3268 non-null   int64
#  3   Sale Price     3268 non-null   int64
#  4   Discount       3268 non-null   int64
#  5   Brand          3268 non-null   object
#  6   Description    3265 non-null   object
#  7   Rating         3268 non-null   float64
#  8   Reviews        3268 non-null   int64
#  9   Last Visited   3268 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 255.4+ KB

# %%
columns
# Out:
# Index(['Product Name', 'Product ID', 'Listing Price', 'Sale Price', 'Discount',
#        'Brand', 'Description', 'Rating', 'Reviews', 'Last Visited'],
#       dtype='object')

# %%
desc
# Out:
#                                     Product Name  Product ID  Listing Price  \
# count                                       3268        3268    3268.000000
# unique                                      1531        3179            NaN
# top     Women's adidas Originals Sambarose Shoes  CD6720-808            NaN
# freq                                          16           3            NaN
# mean                                         NaN         NaN    6868.020196
# std                                          NaN         NaN    4724.659386
# min                                          NaN         NaN       0.000000
# 25%                                          NaN         NaN    4299.000000
# 50%                                          NaN         NaN    5999.000000
# 75%                                          NaN         NaN    8999.000000
# max                                          NaN         NaN   29999.000000
#
#           Sale Price     Discount              Brand  \
# ...

# %%
# HANDLING MISSING VALUES
data.isna().sum()
# Out:
# Product Name     0
# Product ID       0
# Listing Price    0
# Sale Price       0
# Discount         0
# Brand            0
# Description      3
# Rating           0
# Reviews          0
# Last Visited     0
# dtype: int64

# %%
# data is fairly clean except the description column with 3 missing values. 
# We remove these 3 rows because doing so would not affect our final analysis.

data.dropna(axis = 0, inplace=True)

# %%
data.isna().sum()
# Out:
# Product Name     0
# Product ID       0
# Listing Price    0
# Sale Price       0
# Discount         0
# Brand            0
# Description      0
# Rating           0
# Reviews          0
# Last Visited     0
# dtype: int64

# %%
# FEATURE SELECTION

# data['Last Visited'] = data['Last Visited'].apply(lambda x:x.replace('T',' ').split(' '))

# %%
data['Last Visited']
# Out:
# 0       2020-04-13T15:06:14
# 1       2020-04-13T15:06:15
# 2       2020-04-13T15:06:15
# 3       2020-04-13T15:06:15
# 4       2020-04-13T15:06:15
#                ...
# 3263    2020-04-13T15:41:01
# 3264    2020-04-13T15:41:03
# 3265    2020-04-13T15:41:07
# 3266    2020-04-13T15:41:19
# 3267    2020-04-13T15:42:57
# Name: Last Visited, Length: 3265, dtype: object

# %%
for item in data['Last Visited']:
    item1 = item.split('T')[0]
    item2 = item.split('T')[1]
    item = item1 + ' ' + item2
    print(item)
# Out:
# 2020-04-13 15:06:14
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:15
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:16
# 2020-04-13 15:06:17
# 2020-04-13 15:06:17
# 2020-04-13 15:06:17
# 2020-04-13 15:06:17
# 2020-04-13 15:06:17
# 2020-04-13 15:06:17
# 2020-04-13 15:06:17
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:18
# 2020-04-13 15:06:19
# 2020-04-13 15:06:19
# 2020-04-13 15:06:19
# 2020-04-13 15:06:19
# ...

# %%
data['Last Visited'] = pd.to_datetime(data['Last Visited'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3265 entries, 0 to 3267
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   3265 non-null   object
#  1   Product ID     3265 non-null   object
#  2   Listing Price  3265 non-null   int64
#  3   Sale Price     3265 non-null   int64
#  4   Discount       3265 non-null   int64
#  5   Brand          3265 non-null   object
#  6   Description    3265 non-null   object
#  7   Rating         3265 non-null   float64
#  8   Reviews        3265 non-null   int64
#  9   Last Visited   3265 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 280.6+ KB

# %% [markdown]
# # <center>ANALYSIS</center>

# %%
data.sample(3)
# Out:
#                                  Product Name  Product ID  Listing Price  \
# 1982     Men's adidas Originals ZX 4000 Shoes      EE4762           7999
# 3242                    Nike Blazer Low Suede  AV9373-002           6995
# 245   Women's adidas Running Cyberg 1.0 Shoes      CL7321           3599
#
#       Sale Price  Discount              Brand  \
# 1982        4799        40   Adidas ORIGINALS
# 3242        5597         0               Nike
# 245         2159        40  Adidas CORE / NEO
#
#                                             Description  Rating  Reviews  \
# 1982  The ZX series reset the running scene in the '...     4.4       23
# 3242  The Nike Blazer Low Suede Women's Shoe refines...     0.0        0
# 245   Less really is more in these sleek running sho...     4.7       53
#
#             Last Visited
# 1982 2020-04-13 15:07:36
# 3242 2020-04-13 15:38:46
# 245  2020-04-13 15:06:28

# %%
data['Product Name'].nunique()
# Out:
# 1530

# %%
data['Brand'].nunique()
# Out:
# 5

# %%
data['Brand'].value_counts()
# Out:
# Adidas CORE / NEO           1111
# Adidas ORIGINALS             907
# Nike                         640
# Adidas SPORT PERFORMANCE     606
# Adidas Adidas ORIGINALS        1
# Name: Brand, dtype: int64

# %%
data['Rating'].value_counts()
# Out:
# 0.0    302
# 5.0    207
# 4.4    115
# 4.5    114
# 4.2    110
# 4.0    108
# 4.7    108
# 4.8    107
# 4.1    104
# 1.0    101
# 3.5    101
# 4.9     98
# 3.8     98
# 2.8     96
# 4.3     94
# 3.9     92
# 3.0     91
# 2.4     90
# 4.6     90
# 3.7     89
# 3.6     87
# 2.0     86
# 3.1     86
# 2.5     83
# 2.7     83
# 2.6     83
# 2.2     78
# 3.4     75
# 2.9     74
# 3.2     73
# 3.3     72
# 1.5     70
# Name: Rating, dtype: int64
