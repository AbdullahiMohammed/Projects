# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
wh15 = pd.read_csv('datasets/wh_2015.csv')
wh16 = pd.read_csv('datasets/wh_2016.csv')
wh17 = pd.read_csv('datasets/wh_2017.csv')

# %%
wh15
# Out:
#                Country          Region  Happiness Rank  Happiness Score  \
# 0          Switzerland  Western Europe             1.0            7.587
# 1              Iceland  Western Europe             2.0            7.561
# 2              Denmark  Western Europe             3.0            7.527
# 3               Norway  Western Europe             4.0            7.522
# 4               Canada   North America             5.0            7.427
# ..                 ...             ...             ...              ...
# 159            Namibia             NaN             NaN              NaN
# 160        Puerto Rico             NaN             NaN              NaN
# 161            Somalia             NaN             NaN              NaN
# 162  Somaliland Region             NaN             NaN              NaN
# 163        South Sudan             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
wh16
# Out:
#                Country          Region  Happiness Rank  Happiness Score  \
# 0              Denmark  Western Europe             1.0            7.526
# 1          Switzerland  Western Europe             2.0            7.509
# 2              Iceland  Western Europe             3.0            7.501
# 3               Norway  Western Europe             4.0            7.498
# 4              Finland  Western Europe             5.0            7.413
# ..                 ...             ...             ...              ...
# 159            Lesotho             NaN             NaN              NaN
# 160         Mozambique             NaN             NaN              NaN
# 161               Oman             NaN             NaN              NaN
# 162  Somaliland region             NaN             NaN              NaN
# 163          Swaziland             NaN             NaN              NaN
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# ...

# %%
wh17
# Out:
#                Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0               Norway             1.0            7.537      7.594445
# 1              Denmark             2.0            7.522      7.581728
# 2              Iceland             3.0            7.504      7.622030
# 3          Switzerland             4.0            7.494      7.561772
# 4              Finland             5.0            7.469      7.527542
# ..                 ...             ...              ...           ...
# 159        Puerto Rico             NaN              NaN           NaN
# 160  Somaliland Region             NaN              NaN           NaN
# 161  Somaliland region             NaN              NaN           NaN
# 162           Suriname             NaN              NaN           NaN
# 163          Swaziland             NaN              NaN           NaN
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 0       7.479556                  1.616463  1.533524
# ...

# %%
missing15 = wh15['Happiness Score'].isnull()
missing15sum = wh15.isnull().sum()
print(missing15sum)
wh15[missing15]
# Out:
# Country                          0
# Region                           6
# Happiness Rank                   6
# Happiness Score                  6
# Standard Error                   6
# Economy (GDP per Capita)         6
# Family                           6
# Health (Life Expectancy)         6
# Freedom                          6
# Trust (Government Corruption)    6
# Generosity                       6
# Dystopia Residual                6
# Year                             0
# dtype: int64
#                Country Region  Happiness Rank  Happiness Score  \
# 158             Belize    NaN             NaN              NaN
# 159            Namibia    NaN             NaN              NaN
# 160        Puerto Rico    NaN             NaN              NaN
# 161            Somalia    NaN             NaN              NaN
# 162  Somaliland Region    NaN             NaN              NaN
# 163        South Sudan    NaN             NaN              NaN
#
# ...

# %%
missing16 = wh16.isnull().sum()
missing16
# Out:
# Country                          0
# Region                           7
# Happiness Rank                   7
# Happiness Score                  7
# Lower Confidence Interval        7
# Upper Confidence Interval        7
# Economy (GDP per Capita)         7
# Family                           7
# Health (Life Expectancy)         7
# Freedom                          7
# Trust (Government Corruption)    7
# Generosity                       7
# Dystopia Residual                7
# Year                             0
# dtype: int64

# %%
missing17 = wh16.isnull().sum()
missing17
# Out:
# Country                          0
# Region                           7
# Happiness Rank                   7
# Happiness Score                  7
# Lower Confidence Interval        7
# Upper Confidence Interval        7
# Economy (GDP per Capita)         7
# Family                           7
# Health (Life Expectancy)         7
# Freedom                          7
# Trust (Government Corruption)    7
# Generosity                       7
# Dystopia Residual                7
# Year                             0
# dtype: int64

# %%
print(wh15.columns, wh16.columns, wh17.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object') Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object') Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')

# %%
wh15.columns = wh15.columns.str.replace('(', '').str.replace(')', '').str.strip().str.upper()
wh15.columns
# Out:
# Index(['COUNTRY', 'REGION', 'HAPPINESS RANK', 'HAPPINESS SCORE',
#        'STANDARD ERROR', 'ECONOMY GDP PER CAPITA', 'FAMILY',
#        'HEALTH LIFE EXPECTANCY', 'FREEDOM', 'TRUST GOVERNMENT CORRUPTION',
#        'GENEROSITY', 'DYSTOPIA RESIDUAL', 'YEAR'],
#       dtype='object')

# %%
wh16.columns = wh16.columns.str.replace('(', '').str.replace(')', '').str.strip().str.upper()
for item in wh16.columns:
    print(item)
# Out:
# COUNTRY
# REGION
# HAPPINESS RANK
# HAPPINESS SCORE
# LOWER CONFIDENCE INTERVAL
# UPPER CONFIDENCE INTERVAL
# ECONOMY GDP PER CAPITA
# FAMILY
# HEALTH LIFE EXPECTANCY
# FREEDOM
# TRUST GOVERNMENT CORRUPTION
# GENEROSITY
# DYSTOPIA RESIDUAL
# YEAR

# %%
wh17.columns = wh17.columns.str.replace('.', ' ').str.replace('(', '').str.replace(')', '').str.strip().str.upper()
for item in wh17.columns:
    print(item)
# Out:
# COUNTRY
# HAPPINESS RANK
# HAPPINESS SCORE
# WHISKER HIGH
# WHISKER LOW
# ECONOMY  GDP PER CAPITA
# FAMILY
# HEALTH  LIFE EXPECTANCY
# FREEDOM
# GENEROSITY
# TRUST  GOVERNMENT CORRUPTION
# DYSTOPIA RESIDUAL
# YEAR

# %%
wh17 = wh17.rename(columns = {'ECONOMY  GDP PER CAPITA':'ECONOMY GDP PER CAPITA', 'HEALTH  LIFE EXPECTANCY':'HEALTH LIFE EXPECTANCY', 'TRUST  GOVERNMENT CORRUPTION':'TRUST GOVERNMENT CORRUPTION'})
wh17.columns
# Out:
# Index(['COUNTRY', 'HAPPINESS RANK', 'HAPPINESS SCORE', 'WHISKER HIGH',
#        'WHISKER LOW', 'ECONOMY GDP PER CAPITA', 'FAMILY',
#        'HEALTH LIFE EXPECTANCY', 'FREEDOM', 'GENEROSITY',
#        'TRUST GOVERNMENT CORRUPTION', 'DYSTOPIA RESIDUAL', 'YEAR'],
#       dtype='object')

# %%
combined = pd.concat([wh15,wh16,wh17], ignore_index=True)
combined
# Out:
# C:\Users\ADEIZA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                COUNTRY  DYSTOPIA RESIDUAL  ECONOMY GDP PER CAPITA   FAMILY  \
# 0          Switzerland            2.51738                 1.39651  1.34951
# 1              Iceland            2.70201                 1.30232  1.40223
# 2              Denmark            2.49204                 1.32548  1.36058
# 3               Norway            2.46531                 1.45900  1.33095
# 4               Canada            2.45176                 1.32629  1.32261
# ..                 ...                ...                     ...      ...
# ...

# %%
combined.isnull().sum()
# Out:
# COUNTRY                          0
# DYSTOPIA RESIDUAL               22
# ECONOMY GDP PER CAPITA          22
# FAMILY                          22
# FREEDOM                         22
# GENEROSITY                      22
# HAPPINESS RANK                  22
# HAPPINESS SCORE                 22
# HEALTH LIFE EXPECTANCY          22
# LOWER CONFIDENCE INTERVAL      335
# REGION                         177
# STANDARD ERROR                 334
# TRUST GOVERNMENT CORRUPTION     22
# UPPER CONFIDENCE INTERVAL      335
# WHISKER HIGH                   337
# WHISKER LOW                    337
# YEAR                             0
# dtype: int64

# %%
region17 = combined[combined['YEAR'] == 2017]['REGION']
region17.isnull().sum()
# Out:
# 164

# %%
regions = combined[['COUNTRY', 'REGION']]
regions
# Out:
#                COUNTRY          REGION
# 0          Switzerland  Western Europe
# 1              Iceland  Western Europe
# 2              Denmark  Western Europe
# 3               Norway  Western Europe
# 4               Canada   North America
# ..                 ...             ...
# 487        Puerto Rico             NaN
# 488  Somaliland Region             NaN
# 489  Somaliland region             NaN
# 490           Suriname             NaN
# 491          Swaziland             NaN
#
# [492 rows x 2 columns]

# %%
total = pd.merge(right= regions, left = combined, on='COUNTRY', how='left')
total
# Out:
#           COUNTRY  DYSTOPIA RESIDUAL  ECONOMY GDP PER CAPITA   FAMILY  \
# 0     Switzerland            2.51738                 1.39651  1.34951
# 1     Switzerland            2.51738                 1.39651  1.34951
# 2     Switzerland            2.51738                 1.39651  1.34951
# 3         Iceland            2.70201                 1.30232  1.40223
# 4         Iceland            2.70201                 1.30232  1.40223
# ...           ...                ...                     ...      ...
# 1471     Suriname                NaN                     NaN      NaN
# 1472     Suriname                NaN                     NaN      NaN
# 1473    Swaziland                NaN                     NaN      NaN
# 1474    Swaziland                NaN                     NaN      NaN
# 1475    Swaziland                NaN                     NaN      NaN
#
#       FREEDOM  GENEROSITY  HAPPINESS RANK  HAPPINESS SCORE  \
# 0     0.66557     0.29678             1.0            7.587
# ...
