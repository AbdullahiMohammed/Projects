# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re

# %%
    
url = requests.get('https://www.glassdoor.com/Job/nigeria-data-analysts-jobs-SRCH_IL.0,7_IN177_KO8,21.htm?clickSource=searchBox')
html = url.text
soup = bs(html, 'html')
soup.find_all('ul', class_='job-search-key-kgm6qi')
# Out:
# [<ul class="hover p-0 job-search-key-kgm6qi exy0tjh1" data-test="jlGrid"><style data-emotion="job-search-key nhtksm">.job-search-key-nhtksm{box-shadow:0 0 0 0 transparent;border-radius:3px;border-top:1px solid #dee0e3;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin:0;padding:12px 16px;position:relative;}.job-search-key-nhtksm>div{padding:0 12px;}.job-search-key-nhtksm>div:first-child{padding-left:0;-webkit-flex-basis:44px;-ms-flex-preferred-size:44px;flex-basis:44px;}.job-search-key-nhtksm>div:last-child{padding-right:0;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-box-flex:2;-webkit-flex-grow:2;-ms-flex-positive:2;flex-grow:2;}.job-search-key-nhtksm:last-of-type{border-bottom:1px solid #999;}</style><li class="react-job-listing job-search-key-nhtksm eigr9kq0" data-ad-order-id="1136043" data-adv-type="GENERAL" data-brandviews="BRAND:n=jsearch-job-listing:eid=0:jlid=1008091093957" data-id="1008091093957" data-is-easy-apply="true" data-is-orga
# ...

# %%
cards = soup.find_all('li', 'react-job-listing')
len(cards)
# Out:
# 30

# %%
card1 = cards[0]
card1
# Out:
# <span class="job-search-key-9ujsbx euyrj9o0"><style data-emotion="job-search-key 1gje86e">.job-search-key-1gje86e{background:#f5f6f7;font-size:0;display:block;line-height:32px;text-align:center;white-space:nowrap;width:32px;}.job-search-key-1gje86e i{background-image:url('/jobs-ux-app/static/img/core/sprites/sitewide.png');-webkit-background-position:-213px 0;background-position:-213px 0;display:inline-block;height:22px;-webkit-transform:scale(0.8);-moz-transform:scale(0.8);-ms-transform:scale(0.8);transform:scale(0.8);vertical-align:middle;width:20px;}</style><span class="job-search-key-1gje86e euyrj9o1"><i></i></span></span>
